# %% [markdown]
# Geoinformatik 2 – Web-GIS
# # **Übung 3** · Statische, interaktive Webkarte mit Folium & Python
# Prof. Dr. Yu Feng

# %% [markdown]
# ## Lernziele
# Nach dieser Übung können Sie:
# - mit **Folium** (Leaflet in Python) eine interaktive Karte erzeugen,
# - **Punkte**, **Linien** und **Flächen (GeoJSON/Polygon)** visualisieren,
# - Popups/Tooltips und LayerControl nutzen,
# - eine HTML-Datei `*.html` herunterladen.

# %% [markdown]
# ## Reference
#
# Getting started — Folium 0.20.0 documentation
# - https://python-visualization.github.io/folium/latest/getting_started.html#

# %% [markdown]
# ## Setup
# Führe die Zellen nacheinander aus. Falls du deine Ergebnisse im **Google Drive** speichern willst, mounte Drive.

# %%
# (Optional) Google Drive einbinden, damit *.html dort gespeichert wird
#from google.colab import drive
#drive.mount('/content/drive')  # dann Pfade auf /content/drive/MyDrive/... anpassen
#print("Colab-Setup bereit.")

# %% [markdown]
# ## 1) Grundkarte (Basiskarte)

# %%
! pip install folium

# %%
import folium

# Grundkarte erstellen (Zentrum Europa, Zoomstufe 4)
m = folium.Map(location=[50, 10], zoom_start=4, tiles="OpenStreetMap")

# Optional: weitere Basiskarten hinzufügen
folium.TileLayer("CartoDB positron", name="Carto Light").add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bf05c6cf6e21ba6d4f040994b67265ce {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bf05c6cf6e21ba6d4f040994b67265ce&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bf05c6cf6e21ba6d4f040994b67265ce = L.map(
#                 &quot;map_bf05c6cf6e21ba6d4f040994b67265ce&quot;,
#                 {
#                     center: [50.0, 10.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_464cfd1ca1e9352fb18806f8ae04b62e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_464cfd1ca1e9352fb18806f8ae04b62e.addTo(map_bf05c6cf6e21ba6d4f040994b67265ce);
#
#
#             var tile_layer_179588b53dde56bc611ce6197fc8b588 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_179588b53dde56bc611ce6197fc8b588.addTo(map_bf05c6cf6e21ba6d4f040994b67265ce);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Karte speichern
m.save("map_1_basiskarte.html")
print("Gespeichert: map_1_basiskarte.html")
# Out:
# Gespeichert: map_1_basiskarte.html

# %% [markdown]
# ## 2) Punkte (Marker) mit Popup/Tooltip
#
#
# Füge mindestens **3 persönliche Punkte** hinzu, jeweils mit Popup und unterschiedlichen Icons/Farben.

# %%
import folium
from folium import Popup, Icon

# Grundkarte
m = folium.Map(location=[40, 45], zoom_start=3, tiles="OpenStreetMap")
folium.TileLayer("CartoDB positron", name="Carto Light").add_to(m)

# Marker: Titel, (lat, lon), Farbe, Icon, Popup-HTML
punkte = [
    ("Kempenich", (50.4197, 7.1333), "red", "home", "<b>Kempenich</b><br>Heimat"),
    ("Bad Neuenahr-Ahrweiler", (50.5444, 7.1187), "green", "graduation-cap", "<b>Bad Neuenahr-Ahrweiler</b><br>Schulort"),
    ("Mayen", (50.3333, 7.2160), "blue", "briefcase", "<b>Mayen</b><br>Ausbildungsort"),
    ("Mainz", (50.0012, 8.2767), "green", "graduation-cap", "<b>Mainz</b><br>Studiumsort"),
]


bounds = []
for titel, (lat, lon), farbe, icon_name, html in punkte:
    
    folium.Marker(
        location=[lat, lon],
        tooltip=titel,
        popup=Popup(html, max_width=250),
        icon=Icon(color=farbe, icon=icon_name, prefix="fa")  # Font Awesome Icons
    ).add_to(m)


    bounds.append([lat, lon])

if bounds:
    m.fit_bounds(bounds, padding=(20, 20))

folium.LayerControl(collapsed=False).add_to(m)

m.save("map_2_punkte.html")

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a8099a5e4e933e9ae7b76e87ad7b5c5f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a8099a5e4e933e9ae7b76e87ad7b5c5f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a8099a5e4e933e9ae7b76e87ad7b5c5f = L.map(
#                 &quot;map_a8099a5e4e933e9ae7b76e87ad7b5c5f&quot;,
#                 {
#                     center: [40.0, 45.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 3,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d20585cf1a24a1add391f480040d65b3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d20585cf1a24a1add391f480040d65b3.addTo(map_a8099a5e4e933e9ae7b76e87ad7b5c5f);
#
#
#             var tile_layer_036e202d1325f578c0c03bdb07b0019d = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_036e202d1325f578c0c03bdb07b0019d.addTo(map_a8099a5e4e933e9ae7b76e87ad7b5c5f);
#
#
#             var marker_82850a8dc0383271dc355d133f246a62 = L.marker(
#                 [50.4197, 7.1333],
#                 {
# }
#             ).addTo(map_a8099a5e4e933e9ae7b76e87ad7b5c5f);
#
#
#             var icon_00966c426b411be3490ff6ba7eb8768b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_41e31f67cc72dd568dedc1851f598c8a = L.popup({
#   &quot;maxWidth&quot;: 250,
# });
#
#
#
#                 var html_1d3cfc5cad02877682b686b796312182 = $(`&lt;div id=&quot;html_1d3cfc5cad02877682b686b796312182&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Kempenich&lt;/b&gt;&lt;br&gt;Heimat&lt;/div&gt;`)[0];
#                 popup_41e31f67cc72dd568dedc1851f598c8a.setContent(html_1d3cfc5cad02877682b686b796312182);
#
#
#
#         marker_82850a8dc0383271dc355d133f246a62.bindPopup(popup_41e31f67cc72dd568dedc1851f598c8a)
#         ;
#
#
#
#
#             marker_82850a8dc0383271dc355d133f246a62.bindTooltip(
#                 `&lt;div&gt;
#                      Kempenich
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_82850a8dc0383271dc355d133f246a62.setIcon(icon_00966c426b411be3490ff6ba7eb8768b);
#
#
#             var marker_6d6081770c696206c3cc2d90078fe037 = L.marker(
#                 [50.5444, 7.1187],
#                 {
# }
#             ).addTo(map_a8099a5e4e933e9ae7b76e87ad7b5c5f);
#
#
#             var icon_674e3fbdd4802e82767005d5a1fcd40a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;graduation-cap&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_3e235c9322b547c3fd0c86c98e75c834 = L.popup({
#   &quot;maxWidth&quot;: 250,
# });
#
#
#
#                 var html_e66b6870ceb60e8b890908246aa12a1d = $(`&lt;div id=&quot;html_e66b6870ceb60e8b890908246aa12a1d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Bad Neuenahr-Ahrweiler&lt;/b&gt;&lt;br&gt;Schulort&lt;/div&gt;`)[0];
#                 popup_3e235c9322b547c3fd0c86c98e75c834.setContent(html_e66b6870ceb60e8b890908246aa12a1d);
#
#
#
#         marker_6d6081770c696206c3cc2d90078fe037.bindPopup(popup_3e235c9322b547c3fd0c86c98e75c834)
#         ;
#
#
#
#
#             marker_6d6081770c696206c3cc2d90078fe037.bindTooltip(
#                 `&lt;div&gt;
#                      Bad Neuenahr-Ahrweiler
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_6d6081770c696206c3cc2d90078fe037.setIcon(icon_674e3fbdd4802e82767005d5a1fcd40a);

# %%
# Karte speichern
m.save("C:/map_2_punkte.html")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Karte speichern
# ----> 2 m.save("C:/map_2_punkte.html")
#
# File c:\Users\Leon\AppData\Local\Programs\Python\Python313\Lib\site-packages\branca\element.py:227, in Element.save(self, outfile, close_file, **kwargs)
#     225 fid: BinaryIO
#     226 if isinstance(outfile, (str, bytes, Path)):
# --> 227     fid = open(outfile, "wb")
#     228 else:
#     229     fid = outfile
#
# PermissionError: [Errno 13] Permission denied: 'C:/map_2_punkte.html'

# %% [markdown]
# ## 3) Linie (Polyline) – Reiseroute in Sequenz
#
# Erstelle **eine Reiseroute (mind. 3 Stationen)** und prüfe, ob die Nummerierung korrekt erscheint.

# %%
import folium
from folium.features import DivIcon

# Grundkarte über Schottland
m = folium.Map(location=[56.5, -4.5], zoom_start=7, tiles="OpenStreetMap")
folium.TileLayer("CartoDB positron", name="Carto Light").add_to(m)

# Reiseroute (in Reihenfolge)
route = [
    
    ########### Your code here ##############



    #########################################

]

# Polyline einzeichnen

########### Your code here ##############



#########################################

# Stationen nummerieren + Marker mit Tooltip/Popup
for i, (name, (lat, lon)) in enumerate(route, start=1):
    
    ########### Your code here ##############



    #########################################


    # zusätzlicher Marker mit Tooltip/Popup
    ########### Your code here ##############



    #########################################

m

# %%
# Karte speichern
m.save("map_3_reiseroute.html")
print("Gespeichert: map_3_reiseroute.html")

# %% [markdown]
# ## 4) Flächen (Polygon / GeoJSON) – Welt laden & besuchte Länder hervorheben
#
#  Lade ein Welt-GeoJSON (oder nutze den Auto-Download) und hebe besuchte Länder farblich hervor.

# %%
import folium
import requests
from folium import GeoJson

# 1) Welt-GeoJSON ONLINE laden (kein lokaler Download nötig)

########### Your code here ##############



#########################################

# 2) Menge der besuchten Länder – Namen müssen zum GeoJSON passen
#    In dieser Datei heißt das Namensfeld i. d. R. 'name'.
visited = {
    
    ########### Your code here ##############



    #########################################
    
}

# 3) Karte anlegen
m = folium.Map(location=[20, 0], zoom_start=2, tiles="OpenStreetMap")
folium.TileLayer("CartoDB positron", name="Carto Light").add_to(m)

# 4) Styling-Funktionen
def style_fn(feature):
    props = feature.get("properties", {})
    country = props.get("ADMIN") or props.get("name") or ""
    if country in visited:
        return {"fillColor": "#22c55e", "color": "#065f46", "weight": 1, "fillOpacity": 0.6}
    return {"fillColor": "#94a3b8", "color": "#334155", "weight": 0.5, "fillOpacity": 0.15}

def highlight_fn(_):
    return {"fillOpacity": 0.8, "weight": 2, "color": "#0ea5e9"}

# 5) GeoJSON zur Karte hinzufügen
GeoJson(
    data=geojson_data,
    name="World",
    style_function=style_fn,
    highlight_function=highlight_fn,
    tooltip=folium.features.GeoJsonTooltip(
        # Diese Datei nutzt 'name' → falls nötig auf ["ADMIN"] ändern
        fields=["name"],
        aliases=["Land:"],
        sticky=True
    )
).add_to(m)

folium.LayerControl(collapsed=False).add_to(m)

m

# %%
# Karte speichern
m.save("map_4_flaechen_online.html")
print("Gespeichert: map_4_flaechen_online.html")

# %% [markdown]
# ## 5) Checkliste
# - [ ] Füge **mindestens 3** persönliche Punkte hinzu, jeweils mit **Popup** und unterschiedlichen Icons/Farben.
# - [ ] Erstelle eine **Reiseroute** (mind. 3 Stationen) und prüfe, ob die **Nummerierung** korrekt erscheint.
# - [ ] Lade ein Welt-GeoJSON (oder nutze den Auto-Download) und **hebe besuchte Länder** farblich hervor.
# - [ ] Exportiere die Karte als **`maps/*.html`** und **lade** die Datei herunter.
#
# > **Download-Hinweis (Colab):** Rechtsklick auf `*.html` im Dateibrowser von Colab → **Download**.
